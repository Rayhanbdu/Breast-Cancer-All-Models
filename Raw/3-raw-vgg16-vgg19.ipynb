# %%
import json
import math
import os
import gc
import itertools
from functools import partial
from collections import Counter

import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy

from PIL import Image
from tqdm import tqdm

import tensorflow as tf
from tensorflow.keras import layers, backend as K
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (
    Dropout, Flatten, Dense, GlobalAveragePooling2D, Average,
    Input, Concatenate, GlobalMaxPooling2D, BatchNormalization
)
from tensorflow.keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input

from sklearn.model_selection import train_test_split
from sklearn.metrics import cohen_kappa_score, accuracy_score
from sklearn import metrics

# %matplotlib inline
# Out:
# 2026-06-06 13:38:21.738803: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780753101.943569      23 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1780753102.001873      23 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1780753102.489746      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780753102.489788      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780753102.489791      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780753102.489794      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import tensorflow as tf

# Disable XLA
tf.config.optimizer.set_jit(False)

# %%
def Dataset_loader_recursive(DIR, RESIZE):
    IMG = []
    
    for root, _, files in os.walk(DIR):
        for file in files:
            PATH = os.path.join(root, file)
            _, ftype = os.path.splitext(PATH)
            
            if ftype.lower() in [".jpg", ".jpeg", ".png"]:
                try:
                    img = np.asarray(Image.open(PATH).convert("RGB"))
                    img = cv2.resize(img, (RESIZE, RESIZE))
                    IMG.append(img)
                except:
                    continue
    
    return np.array(IMG)
DIR = "/kaggle/input/datasets/tueoban/aisslab-breast-cancer-sub-datasets/AISSLab Sub-datasets/Raw Sub-datasets/AISSLab-v5"

benign_bi_rads_2 = Dataset_loader_recursive(os.path.join(DIR, "BI-RADS 2"), RESIZE=224)
benign_bi_rads_3 = Dataset_loader_recursive(os.path.join(DIR, "BI-RADS 3"), RESIZE=224)

malignant_bi_rads_4 = Dataset_loader_recursive(os.path.join(DIR, "BI-RADS 4"), RESIZE=224)
malignant_bi_rads_5 = Dataset_loader_recursive(os.path.join(DIR, "BI-RADS 5"), RESIZE=224)

#normal = Dataset_loader_recursive(os.path.join(DIR, "Normal/JPG/"), RESIZE=224)

# %%
print("Total images loaded:", len(benign_bi_rads_2))
print("Shape:", benign_bi_rads_2.shape)

print("Total images loaded:", len(benign_bi_rads_3))
print("Shape:", benign_bi_rads_3.shape)

print("Total images loaded:", len(malignant_bi_rads_4))
print("Shape:", malignant_bi_rads_4.shape)

print("Total images loaded:", len(malignant_bi_rads_5))
print("Shape:", malignant_bi_rads_5.shape)
# Out:
# Total images loaded: 18
# Shape: (18, 224, 224, 3)
# Total images loaded: 48
# Shape: (48, 224, 224, 3)
# Total images loaded: 54
# Shape: (54, 224, 224, 3)
# Total images loaded: 46
# Shape: (46, 224, 224, 3)

# %%
#normal_label = np.full(len(normal),0)
benign_bi_rads_2_label = np.full(len(benign_bi_rads_2), 0)
benign_bi_rads_3_label = np.full(len(benign_bi_rads_3),1)
malignant_bi_rads_4_label = np.full(len(malignant_bi_rads_4),2)
malignant_bi_rads_5_label = np.full(len(malignant_bi_rads_5),3)

# %%
X = np.concatenate((benign_bi_rads_2, benign_bi_rads_3, malignant_bi_rads_4, malignant_bi_rads_5), axis = 0)
Y = np.concatenate((benign_bi_rads_2_label, benign_bi_rads_3_label, malignant_bi_rads_4_label, malignant_bi_rads_5_label), axis = 0)

# Shuffle train data
s = np.arange(X.shape[0])
np.random.shuffle(s)
X = X[s]
Y = Y[s]

# DENSENET PREPROCESSING
X = preprocess_input(
    X.astype("float32")
)
x_train, x_test, y_train, y_test = train_test_split(
    X, Y, 
    test_size=0.2, 
    random_state=11,
    stratify=Y
)

# %%
x_train, x_val, y_train, y_val = train_test_split(
    x_train,
    y_train,
    test_size=0.2,
    random_state=11,
    stratify=y_train
)

print("\nFinal Shapes:")
print("x_train:", x_train.shape)
print("y_train:", y_train.shape)
print("x_val:", x_val.shape)
print("y_val:", y_val.shape)
print("x_test:", x_test.shape)
print("y_test:", y_test.shape)
# Out:
# Final Shapes:
# x_train: (105, 224, 224, 3)
# y_train: (105,)
# x_val: (27, 224, 224, 3)
# y_val: (27,)
# x_test: (34, 224, 224, 3)
# y_test: (34,)

# %%
from imblearn.over_sampling import RandomOverSampler
from tensorflow.keras.utils import to_categorical
from collections import Counter
import numpy as np

# Convert one-hot -> labels if needed
if len(y_train.shape) > 1:
    y_train_labels = np.argmax(y_train, axis=1)
else:
    y_train_labels = y_train

# Check original distribution
print("Original class distribution:")
print(Counter(y_train_labels))

# Flatten image data temporarily
nsamples, h, w, c = x_train.shape

x_train_flat = x_train.reshape(
    (nsamples, h * w * c)
)

target = 1200

sampling_strategy = {
    0: target,
    1: target,
    2: target,
    3: target
}

# Apply Oversampling
ros = RandomOverSampler(
    sampling_strategy=sampling_strategy,
    random_state=42
)

x_train, y_train = ros.fit_resample(
    x_train_flat,
    y_train_labels
)

# Restore image shape
x_train = x_train.reshape(
    (-1, h, w, c)
)

# One-hot Encode Labels
y_train = to_categorical(
    y_train,
    num_classes=4
)

# Validation labels
if len(y_val.shape) == 1:
    y_val = to_categorical(y_val, num_classes=4)

# Test labels
if len(y_test.shape) == 1:
    y_test = to_categorical(y_test, num_classes=4)

# Final Distribution
print("\nBalanced class distribution:")
print(Counter(np.argmax(y_train, axis=1)))
# Out:
# Original class distribution:
# Counter({np.int64(2): 34, np.int64(3): 30, np.int64(1): 30, np.int64(0): 11})
#
# Balanced class distribution:
# Counter({np.int64(2): 1200, np.int64(3): 1200, np.int64(0): 1200, np.int64(1): 1200})

# %%
BATCH_SIZE = 32

# Using original generator
train_generator = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.2,
    shear_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    vertical_flip=False
)

# %%
from tensorflow.keras.applications import VGG16, VGG19

# %%
from tensorflow.keras.applications import VGG16, VGG19
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input,
    Dense,
    Dropout,
    BatchNormalization,
    GlobalAveragePooling2D
)

from tensorflow.keras.optimizers import Adam
def build_model(model_name):
    inputs = Input(shape=(224,224,3))

    # SELECT MODEL
    if model_name == "VGG16":

        base_model = VGG16(
            weights='imagenet',
            include_top=False,
            input_tensor=inputs
        )

    elif model_name == "VGG19":

        base_model = VGG19(
            weights='imagenet',
            include_top=False,
            input_tensor=inputs
        )

    # FREEZE LAYERS
    for layer in base_model.layers:
        layer.trainable = False

    # CUSTOM HEAD
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.4)(x)
    outputs = Dense(4, activation='softmax')(x)

    # FINAL MODEL
    model = Model(inputs, outputs)

    # COMPILE
    model.compile(
        optimizer=Adam(learning_rate=1e-4),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    return model, base_model

# %%
from tensorflow.keras.callbacks import (
    ModelCheckpoint,
    EarlyStopping,
    ReduceLROnPlateau
)

def get_callbacks(model_name):

    checkpoint = ModelCheckpoint(
        f"/kaggle/working/{model_name}_best.keras",
        monitor='val_accuracy',
        save_best_only=True,
        mode='max',
        verbose=1
    )

    earlystop = EarlyStopping(
        monitor='val_accuracy',
        patience=8,
        restore_best_weights=True,
        mode='max',
        verbose=1
    )

    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.3,
        patience=3,
        min_lr=1e-6,
        verbose=1
    )

    return [checkpoint, earlystop, reduce_lr]

# %%
def train_model(model, model_name):
    history = model.fit(
        train_generator.flow(
            x_train,
            y_train,
            batch_size=32
        ),
        steps_per_epoch=x_train.shape[0] // 32,
        validation_data=(x_val, y_val),
        epochs=30,
        callbacks=get_callbacks(model_name)
    )
    return history

# %%
def fine_tune_model(model, base_model, model_name):

    # Unfreeze last 4 layers
    for layer in base_model.layers[-4:]:
        layer.trainable = True

    # Recompile
    model.compile(
        optimizer=Adam(learning_rate=1e-5),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    history_fine = model.fit(
        train_generator.flow(
            x_train,
            y_train,
            batch_size=32
        ),
        steps_per_epoch=x_train.shape[0] // 32,
        validation_data=(x_val, y_val),
        epochs=30,
        callbacks=get_callbacks(model_name)
    )

    return history_fine

# %%
# BUILD MODEL
model_vgg16, base_vgg16 = build_model("VGG16")

# TRAIN
history_vgg16 = train_model(model_vgg16,"VGG16")

# FINE TUNE
history_vgg16_fine = fine_tune_model(model_vgg16,base_vgg16,"VGG16")
# Out:
# I0000 00:00:1780753155.707710      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1780753155.713600      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1780753162.338391      69 service.cc:152] XLA service 0x7b8dc0005d40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1780753162.338431      69 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1780753162.338437      69 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1780753162.938977      69 cuda_dnn.cc:529] Loaded cuDNN version 91002
#   1/150 ━━━━━━━━━━━━━━━━━━━━ 42:28 17s/step - accuracy: 0.2188 - loss: 2.5194
# I0000 00:00:1780753177.086657      69 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.2752 - loss: 2.1416
# Epoch 1: val_accuracy improved from None to 0.25926, saving model to /kaggle/working/VGG16_best.keras
#
# Epoch 1: finished saving model to /kaggle/working/VGG16_best.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 79s 413ms/step - accuracy: 0.3173 - loss: 1.9701 - val_accuracy: 0.2593 - val_loss: 1.8514 - learning_rate: 1.0000e-04
# Epoch 2/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.4058 - loss: 1.5913
# Epoch 2: val_accuracy did not improve from 0.25926
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 49s 322ms/step - accuracy: 0.4269 - loss: 1.5323 - val_accuracy: 0.1852 - val_loss: 1.6594 - learning_rate: 1.0000e-04
# Epoch 3/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.4594 - loss: 1.4351
# Epoch 3: val_accuracy did not improve from 0.25926
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 50s 331ms/step - accuracy: 0.4723 - loss: 1.3846 - val_accuracy: 0.2222 - val_loss: 1.5540 - learning_rate: 1.0000e-04
# Epoch 4/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.5172 - loss: 1.2482
# Epoch 4: val_accuracy did not improve from 0.25926
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 51s 336ms/step - accuracy: 0.5198 - loss: 1.2359 - val_accuracy: 0.2222 - val_loss: 1.5204 - learning_rate: 1.0000e-04
# Epoch 5/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.5484 - loss: 1.1510
# Epoch 5: val_accuracy did not improve from 0.25926
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 55s 367ms/step - accuracy: 0.5533 - loss: 1.1360 - val_accuracy: 0.2593 - val_loss: 1.4734 - learning_rate: 1.0000e-04
# Epoch 6/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.5770 - loss: 1.1017
# Epoch 6: val_accuracy improved from 0.25926 to 0.29630, saving model to /kaggle/working/VGG16_best.keras
#
# Epoch 6: finished saving model to /kaggle/working/VGG16_best.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 55s 365ms/step - accuracy: 0.5819 - loss: 1.0758 - val_accuracy: 0.2963 - val_loss: 1.4825 - learning_rate: 1.0000e-04
# Epoch 7/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.6070 - loss: 0.9565
# Epoch 7: val_accuracy did not improve from 0.29630
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 54s 358ms/step - accuracy: 0.6044 - loss: 0.9782 - val_accuracy: 0.2593 - val_loss: 1.5057 - learning_rate: 1.0000e-04
# Epoch 8/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.6232 - loss: 0.9576
# Epoch 8: val_accuracy did not improve from 0.29630
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 51s 340ms/step - accuracy: 0.6260 - loss: 0.9527 - val_accuracy: 0.2593 - val_loss: 1.5273 - learning_rate: 1.0000e-04
# Epoch 9/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.6292 - loss: 0.9240
# Epoch 9: val_accuracy did not improve from 0.29630
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 52s 348ms/step - accuracy: 0.6294 - loss: 0.9280 - val_accuracy: 0.2593 - val_loss: 1.5280 - learning_rate: 3.0000e-05
# Epoch 10/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.6541 - loss: 0.9023
# Epoch 10: val_accuracy did not improve from 0.29630
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 52s 343ms/step - accuracy: 0.6456 - loss: 0.9071 - val_accuracy: 0.2593 - val_loss: 1.5154 - learning_rate: 3.0000e-05
# Epoch 11/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.6577 - loss: 0.8671
# Epoch 11: val_accuracy did not improve from 0.29630
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 52s 343ms/step - accuracy: 0.6498 - loss: 0.8856 - val_accuracy: 0.2593 - val_loss: 1.5080 - learning_rate: 3.0000e-05
# Epoch 12/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.6594 - loss: 0.8845
# Epoch 12: val_accuracy did not improve from 0.29630
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 51s 338ms/step - accuracy: 0.6488 - loss: 0.8962 - val_accuracy: 0.2593 - val_loss: 1.5023 - learning_rate: 9.0000e-06
# Epoch 13/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.6594 - loss: 0.8816
# Epoch 13: val_accuracy did not improve from 0.29630
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 51s 341ms/step - accuracy: 0.6581 - loss: 0.8751 - val_accuracy: 0.2593 - val_loss: 1.5043 - learning_rate: 9.0000e-06
# Epoch 14/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.6440 - loss: 0.8973
# Epoch 14: val_accuracy did not improve from 0.29630
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 52s 344ms/step - accuracy: 0.6456 - loss: 0.8891 - val_accuracy: 0.2963 - val_loss: 1.4838 - learning_rate: 9.0000e-06
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Epoch 1/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.6399 - loss: 0.9162
# Epoch 1: val_accuracy improved from None to 0.29630, saving model to /kaggle/working/VGG16_best.keras
#
# Epoch 1: finished saving model to /kaggle/working/VGG16_best.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 61s 352ms/step - accuracy: 0.6579 - loss: 0.8659 - val_accuracy: 0.2963 - val_loss: 1.4454 - learning_rate: 1.0000e-05
# Epoch 2/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.7247 - loss: 0.6972
# Epoch 2: val_accuracy improved from 0.29630 to 0.40741, saving model to /kaggle/working/VGG16_best.keras
#
# Epoch 2: finished saving model to /kaggle/working/VGG16_best.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 53s 351ms/step - accuracy: 0.7419 - loss: 0.6526 - val_accuracy: 0.4074 - val_loss: 1.5630 - learning_rate: 1.0000e-05
# Epoch 3/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.7965 - loss: 0.5450
# Epoch 3: val_accuracy did not improve from 0.40741
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 52s 345ms/step - accuracy: 0.8067 - loss: 0.5011 - val_accuracy: 0.4074 - val_loss: 1.4761 - learning_rate: 1.0000e-05
# Epoch 4/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - accuracy: 0.8263 - loss: 0.4296
# Epoch 4: val_accuracy improved from 0.40741 to 0.44444, saving model to /kaggle/working/VGG16_best.keras
#
# Epoch 4: finished saving model to /kaggle/working/VGG16_best.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 55s 367ms/step - accuracy: 0.8446 - loss: 0.4028 - val_accuracy: 0.4444 - val_loss: 1.4365 - learning_rate: 1.0000e-05
# Epoch 5/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.8762 - loss: 0.3347
# Epoch 5: val_accuracy improved from 0.44444 to 0.48148, saving model to /kaggle/working/VGG16_best.keras
#
# Epoch 5: finished saving model to /kaggle/working/VGG16_best.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 57s 380ms/step - accuracy: 0.8825 - loss: 0.3212 - val_accuracy: 0.4815 - val_loss: 1.3914 - learning_rate: 1.0000e-05
# Epoch 6/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 0.9109 - loss: 0.2679
# Epoch 6: val_accuracy did not improve from 0.48148
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 57s 381ms/step - accuracy: 0.9137 - loss: 0.2519 - val_accuracy: 0.4815 - val_loss: 1.4904 - learning_rate: 1.0000e-05
# Epoch 7/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.9261 - loss: 0.2216
# Epoch 7: val_accuracy improved from 0.48148 to 0.51852, saving model to /kaggle/working/VGG16_best.keras
#
# Epoch 7: finished saving model to /kaggle/working/VGG16_best.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 54s 361ms/step - accuracy: 0.9281 - loss: 0.2131 - val_accuracy: 0.5185 - val_loss: 1.3874 - learning_rate: 1.0000e-05
# Epoch 8/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.9460 - loss: 0.1797
# Epoch 8: val_accuracy did not improve from 0.51852
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 56s 373ms/step - accuracy: 0.9433 - loss: 0.1787 - val_accuracy: 0.4444 - val_loss: 1.4310 - learning_rate: 1.0000e-05
# Epoch 9/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.9537 - loss: 0.1537
# Epoch 9: val_accuracy improved from 0.51852 to 0.55556, saving model to /kaggle/working/VGG16_best.keras
#
# Epoch 9: finished saving model to /kaggle/working/VGG16_best.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 55s 369ms/step - accuracy: 0.9540 - loss: 0.1533 - val_accuracy: 0.5556 - val_loss: 1.3834 - learning_rate: 1.0000e-05
# Epoch 10/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.9601 - loss: 0.1371
# Epoch 10: val_accuracy did not improve from 0.55556
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 54s 360ms/step - accuracy: 0.9617 - loss: 0.1317 - val_accuracy: 0.5185 - val_loss: 1.2924 - learning_rate: 1.0000e-05
# Epoch 11/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.9651 - loss: 0.1210
# Epoch 11: val_accuracy did not improve from 0.55556
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 54s 361ms/step - accuracy: 0.9667 - loss: 0.1179 - val_accuracy: 0.4444 - val_loss: 1.3824 - learning_rate: 1.0000e-05
# Epoch 12/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9707 - loss: 0.1057
# Epoch 12: val_accuracy did not improve from 0.55556
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 53s 351ms/step - accuracy: 0.9742 - loss: 0.1019 - val_accuracy: 0.4444 - val_loss: 1.5341 - learning_rate: 1.0000e-05
# Epoch 13/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.9763 - loss: 0.0837
# Epoch 13: val_accuracy did not improve from 0.55556
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 2.9999999242136253e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 55s 366ms/step - accuracy: 0.9742 - loss: 0.0894 - val_accuracy: 0.4815 - val_loss: 1.5291 - learning_rate: 1.0000e-05
# Epoch 14/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.9816 - loss: 0.0781
# Epoch 14: val_accuracy did not improve from 0.55556
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 53s 351ms/step - accuracy: 0.9823 - loss: 0.0750 - val_accuracy: 0.4815 - val_loss: 1.5248 - learning_rate: 3.0000e-06
# Epoch 15/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.9846 - loss: 0.0654
# Epoch 15: val_accuracy did not improve from 0.55556
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 53s 355ms/step - accuracy: 0.9810 - loss: 0.0722 - val_accuracy: 0.5185 - val_loss: 1.5562 - learning_rate: 3.0000e-06
# Epoch 16/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.9807 - loss: 0.0705
# Epoch 16: val_accuracy did not improve from 0.55556
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 55s 366ms/step - accuracy: 0.9808 - loss: 0.0707 - val_accuracy: 0.4444 - val_loss: 1.5741 - learning_rate: 3.0000e-06
# Epoch 17/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.9890 - loss: 0.0581
# Epoch 17: val_accuracy did not improve from 0.55556
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 54s 356ms/step - accuracy: 0.9858 - loss: 0.0645 - val_accuracy: 0.5185 - val_loss: 1.5286 - learning_rate: 1.0000e-06
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 9.

# %%
pred_vgg16 = model_vgg16.predict(x_test)
y_pred_vgg16 = np.argmax(pred_vgg16, axis=1)
y_true = np.argmax(y_test, axis=1)

from sklearn.metrics import accuracy_score

acc_vgg16 = accuracy_score(y_true,y_pred_vgg16)
print("VGG16 Accuracy:", acc_vgg16)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 3s/step
# VGG16 Accuracy: 0.2647058823529412

# %%
import gc
import tensorflow as tf

tf.keras.backend.clear_session()

gc.collect()
# Out:
# 0

# %%
# BUILD MODEL
model_vgg19, base_vgg19 = build_model("VGG19")

# TRAIN
history_vgg19 = train_model(model_vgg19,"VGG19")

# FINE TUNE
history_vgg19_fine = fine_tune_model(model_vgg19,base_vgg19,"VGG19")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Epoch 1/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.2771 - loss: 2.1287
# Epoch 1: val_accuracy improved from None to 0.33333, saving model to /kaggle/working/VGG19_best.keras
#
# Epoch 1: finished saving model to /kaggle/working/VGG19_best.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 58s 358ms/step - accuracy: 0.3198 - loss: 1.9694 - val_accuracy: 0.3333 - val_loss: 1.7553 - learning_rate: 1.0000e-04
# Epoch 2/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.4104 - loss: 1.6481
# Epoch 2: val_accuracy did not improve from 0.33333
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 52s 347ms/step - accuracy: 0.4150 - loss: 1.6148 - val_accuracy: 0.2963 - val_loss: 1.6284 - learning_rate: 1.0000e-04
# Epoch 3/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.4745 - loss: 1.3932
# Epoch 3: val_accuracy did not improve from 0.33333
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 53s 353ms/step - accuracy: 0.4910 - loss: 1.3509 - val_accuracy: 0.2593 - val_loss: 1.6656 - learning_rate: 1.0000e-04
# Epoch 4/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.5255 - loss: 1.2602
# Epoch 4: val_accuracy did not improve from 0.33333
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 53s 352ms/step - accuracy: 0.5275 - loss: 1.2393 - val_accuracy: 0.2222 - val_loss: 1.6950 - learning_rate: 1.0000e-04
# Epoch 5/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.5413 - loss: 1.2010
# Epoch 5: val_accuracy did not improve from 0.33333
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 53s 354ms/step - accuracy: 0.5525 - loss: 1.1638 - val_accuracy: 0.1852 - val_loss: 1.7873 - learning_rate: 1.0000e-04
# Epoch 6/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.5673 - loss: 1.1055
# Epoch 6: val_accuracy did not improve from 0.33333
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 53s 353ms/step - accuracy: 0.5648 - loss: 1.1234 - val_accuracy: 0.2222 - val_loss: 1.8072 - learning_rate: 3.0000e-05
# Epoch 7/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.5689 - loss: 1.0663
# Epoch 7: val_accuracy did not improve from 0.33333
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 53s 353ms/step - accuracy: 0.5729 - loss: 1.0794 - val_accuracy: 0.2222 - val_loss: 1.8066 - learning_rate: 3.0000e-05
# Epoch 8/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.5734 - loss: 1.0644
# Epoch 8: val_accuracy did not improve from 0.33333
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 53s 351ms/step - accuracy: 0.5746 - loss: 1.0600 - val_accuracy: 0.1852 - val_loss: 1.8176 - learning_rate: 3.0000e-05
# Epoch 9/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.5772 - loss: 1.0767
# Epoch 9: val_accuracy did not improve from 0.33333
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 53s 353ms/step - accuracy: 0.5873 - loss: 1.0654 - val_accuracy: 0.1852 - val_loss: 1.8243 - learning_rate: 9.0000e-06
# Epoch 9: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Epoch 1/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.4138 - loss: 1.6109
# Epoch 1: val_accuracy improved from None to 0.33333, saving model to /kaggle/working/VGG19_best.keras
#
# Epoch 1: finished saving model to /kaggle/working/VGG19_best.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 62s 378ms/step - accuracy: 0.4490 - loss: 1.4874 - val_accuracy: 0.3333 - val_loss: 1.6160 - learning_rate: 1.0000e-05
# Epoch 2/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.5447 - loss: 1.1904
# Epoch 2: val_accuracy did not improve from 0.33333
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 55s 362ms/step - accuracy: 0.5706 - loss: 1.1162 - val_accuracy: 0.2963 - val_loss: 1.7502 - learning_rate: 1.0000e-05
# Epoch 3/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.6353 - loss: 0.9479
# Epoch 3: val_accuracy improved from 0.33333 to 0.37037, saving model to /kaggle/working/VGG19_best.keras
#
# Epoch 3: finished saving model to /kaggle/working/VGG19_best.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 55s 363ms/step - accuracy: 0.6554 - loss: 0.9018 - val_accuracy: 0.3704 - val_loss: 1.7151 - learning_rate: 1.0000e-05
# Epoch 4/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.7244 - loss: 0.7095
# Epoch 4: val_accuracy did not improve from 0.37037
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 2.9999999242136253e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 55s 368ms/step - accuracy: 0.7340 - loss: 0.6790 - val_accuracy: 0.3333 - val_loss: 1.8801 - learning_rate: 1.0000e-05
# Epoch 5/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.7592 - loss: 0.6139
# Epoch 5: val_accuracy did not improve from 0.37037
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 56s 371ms/step - accuracy: 0.7725 - loss: 0.5884 - val_accuracy: 0.3704 - val_loss: 1.8190 - learning_rate: 3.0000e-06
# Epoch 6/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.7813 - loss: 0.5467
# Epoch 6: val_accuracy did not improve from 0.37037
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 55s 365ms/step - accuracy: 0.7929 - loss: 0.5391 - val_accuracy: 0.3704 - val_loss: 1.8431 - learning_rate: 3.0000e-06
# Epoch 7/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.8045 - loss: 0.5153
# Epoch 7: val_accuracy did not improve from 0.37037
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 1e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 54s 358ms/step - accuracy: 0.7994 - loss: 0.5177 - val_accuracy: 0.3333 - val_loss: 1.8871 - learning_rate: 3.0000e-06
# Epoch 8/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.8073 - loss: 0.4968
# Epoch 8: val_accuracy did not improve from 0.37037
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 53s 354ms/step - accuracy: 0.8115 - loss: 0.4920 - val_accuracy: 0.2963 - val_loss: 1.8914 - learning_rate: 1.0000e-06
# Epoch 9/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.8118 - loss: 0.4866
# Epoch 9: val_accuracy did not improve from 0.37037
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 56s 369ms/step - accuracy: 0.8110 - loss: 0.4875 - val_accuracy: 0.3333 - val_loss: 1.9150 - learning_rate: 1.0000e-06
# Epoch 10/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.8171 - loss: 0.4629
# Epoch 10: val_accuracy did not improve from 0.37037
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 56s 370ms/step - accuracy: 0.8183 - loss: 0.4747 - val_accuracy: 0.3333 - val_loss: 1.8989 - learning_rate: 1.0000e-06
# Epoch 11/30
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.8310 - loss: 0.4528
# Epoch 11: val_accuracy did not improve from 0.37037
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 55s 366ms/step - accuracy: 0.8348 - loss: 0.4437 - val_accuracy: 0.2963 - val_loss: 1.8880 - learning_rate: 1.0000e-06
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 3.

# %%
from sklearn.metrics import (classification_report,confusion_matrix,accuracy_score,precision_score,recall_score,f1_score,matthews_corrcoef,mean_absolute_error,mean_squared_error,cohen_kappa_score)
import itertools
def evaluate_model(model, model_name):

    print(f"\n{'='*50}")
    print(f"{model_name} EVALUATION")
    print(f"{'='*50}")

    # Prediction
    pred = model.predict(x_test)
    y_pred = np.argmax(pred, axis=1)
    y_true = np.argmax(y_test, axis=1)

    # Accuracy
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true,y_pred,average='weighted')
    recall = recall_score(y_true,y_pred,average='weighted')

    f1 = f1_score(y_true,y_pred,average='weighted')
    mcc = matthews_corrcoef(y_true, y_pred )
    kappa = cohen_kappa_score(y_true,y_pred )

    # Classification Report
    print("\nClassification Report:\n")

    target_names = ['Benign (BI-RADS 2)','Benign (BI-RADS 3)','Malign (BI-RADS 4)','Malign (BI-RADS 5)']
    print(classification_report(y_true,y_pred,target_names=target_names))

    # Confusion Matrix
    cm = confusion_matrix(y_true, y_pred)
    print("\nConfusion Matrix:\n")
    print(cm)
    # Plot CM
    plt.figure(figsize=(6,6))
    plt.imshow(cm, cmap=plt.cm.Blues)
    plt.title(f'{model_name} Confusion Matrix')
    plt.colorbar()
    tick_marks = np.arange(len(target_names))
    plt.xticks(tick_marks,target_names,rotation=45)
    plt.yticks(tick_marks,target_names)
    thresh = cm.max() / 2.

    for i, j in itertools.product(range(cm.shape[0]),range(cm.shape[1])):
        plt.text(j,i,
            format(cm[i, j], 'd'),
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black"
        )
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.show()
    # Final Metrics
    print("\nAdditional Metrics:\n")
    print(f"Accuracy       : {accuracy:.4f}")
    print(f"Precision      : {precision:.4f}")
    print(f"Recall         : {recall:.4f}")
    print(f"F1-score       : {f1:.4f}")
    print(f"MCC            : {mcc:.4f}")
    print(f"Cohen Kappa    : {kappa:.4f}")
    return accuracy

# %%
acc_vgg16 = evaluate_model(
    model_vgg16,
    "VGG16"
)
# Out:
# ==================================================
# VGG16 EVALUATION
# ==================================================
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
#
# Classification Report:
#
#                     precision    recall  f1-score   support
#
# Benign (BI-RADS 2)       0.00      0.00      0.00         4
# Benign (BI-RADS 3)       0.33      0.10      0.15        10
# Malign (BI-RADS 4)       0.33      0.36      0.35        11
# Malign (BI-RADS 5)       0.24      0.44      0.31         9
#
#           accuracy                           0.26        34
#          macro avg       0.23      0.23      0.20        34
#       weighted avg       0.27      0.26      0.24        34
#
#
# Confusion Matrix:
#
# [[0 0 0 4]
#  [2 1 3 4]
#  [0 2 4 5]
#  [0 0 5 4]]
# Additional Metrics:
#
# Accuracy       : 0.2647
# Precision      : 0.2682
# Recall         : 0.2647
# F1-score       : 0.2392
# MCC            : -0.0220
# Cohen Kappa    : -0.0204

# %%
acc_vgg19 = evaluate_model(
    model_vgg19,
    "VGG19"
)
# Out:
# ==================================================
# VGG19 EVALUATION
# ==================================================
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 749ms/step
#
# Classification Report:
#
#                     precision    recall  f1-score   support
#
# Benign (BI-RADS 2)       0.00      0.00      0.00         4
# Benign (BI-RADS 3)       0.30      0.30      0.30        10
# Malign (BI-RADS 4)       0.33      0.27      0.30        11
# Malign (BI-RADS 5)       0.50      0.56      0.53         9
#
#           accuracy                           0.32        34
#          macro avg       0.28      0.28      0.28        34
#       weighted avg       0.33      0.32      0.32        34
#
#
# Confusion Matrix:
#
# [[0 0 2 2]
#  [2 3 2 3]
#  [3 5 3 0]
#  [0 2 2 5]]
# Additional Metrics:
#
# Accuracy       : 0.3235
# Precision      : 0.3284
# Recall         : 0.3235
# F1-score       : 0.3246
# MCC            : 0.0770
# Cohen Kappa    : 0.0767

# %%
print("\nFINAL COMPARISON")
print("="*40)

print(f"VGG16 Accuracy : {acc_vgg16:.4f}")

print(f"VGG19 Accuracy : {acc_vgg19:.4f}")

if acc_vgg16 > acc_vgg19:

    print("\nBest Model : VGG16")

else:

    print("\nBest Model : VGG19")
# Out:
# FINAL COMPARISON
# ========================================
# VGG16 Accuracy : 0.2647
# VGG19 Accuracy : 0.3235
#
# Best Model : VGG19
