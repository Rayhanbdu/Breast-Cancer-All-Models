# %%
import json
import math
import os
import gc
import itertools
from functools import partial
from collections import Counter

import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy

from PIL import Image
from tqdm import tqdm

import tensorflow as tf
from tensorflow.keras import layers, backend as K
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (
    Dropout, Flatten, Dense, GlobalAveragePooling2D, Average,
    Input, Concatenate, GlobalMaxPooling2D, BatchNormalization
)
from tensorflow.keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam

# Applications (ALL from tensorflow.keras)
from tensorflow.keras.applications import (
    ResNet50,
    EfficientNetV2B0,
    VGG16
)

from sklearn.model_selection import train_test_split
from sklearn.metrics import cohen_kappa_score, accuracy_score
from sklearn import metrics

# %matplotlib inline
# Out:
# 2026-06-06 18:12:52.726333: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780769572.929156      23 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1780769572.986511      23 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1780769573.455659      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780769573.455701      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780769573.455704      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780769573.455706      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import tensorflow as tf

# Disable XLA
tf.config.optimizer.set_jit(False)

# %%
def Dataset_loader_recursive(DIR, RESIZE):
    IMG = []
    
    for root, _, files in os.walk(DIR):
        for file in files:
            PATH = os.path.join(root, file)
            _, ftype = os.path.splitext(PATH)
            
            if ftype.lower() in [".jpg", ".jpeg", ".png"]:
                try:
                    img = np.asarray(Image.open(PATH).convert("RGB"))
                    img = cv2.resize(img, (RESIZE, RESIZE))
                    IMG.append(img)
                except:
                    continue
    
    return np.array(IMG)
DIR = "/kaggle/input/datasets/tueoban/aisslab-breast-cancer-sub-datasets/AISSLab Sub-datasets/Raw Sub-datasets/AISSLab-v5"

benign_bi_rads_2 = Dataset_loader_recursive(os.path.join(DIR, "BI-RADS 2"), RESIZE=224)
benign_bi_rads_3 = Dataset_loader_recursive(os.path.join(DIR, "BI-RADS 3"), RESIZE=224)

malignant_bi_rads_4 = Dataset_loader_recursive(os.path.join(DIR, "BI-RADS 4"), RESIZE=224)
malignant_bi_rads_5 = Dataset_loader_recursive(os.path.join(DIR, "BI-RADS 5"), RESIZE=224)

#normal = Dataset_loader_recursive(os.path.join(DIR, "Normal/JPG/"), RESIZE=224)

# %%
print("Total images loaded:", len(benign_bi_rads_2))
print("Shape:", benign_bi_rads_2.shape)

print("Total images loaded:", len(benign_bi_rads_3))
print("Shape:", benign_bi_rads_3.shape)

print("Total images loaded:", len(malignant_bi_rads_4))
print("Shape:", malignant_bi_rads_4.shape)

print("Total images loaded:", len(malignant_bi_rads_5))
print("Shape:", malignant_bi_rads_5.shape)
# Out:
# Total images loaded: 18
# Shape: (18, 224, 224, 3)
# Total images loaded: 48
# Shape: (48, 224, 224, 3)
# Total images loaded: 54
# Shape: (54, 224, 224, 3)
# Total images loaded: 46
# Shape: (46, 224, 224, 3)

# %%
#normal_label = np.full(len(normal),0)
benign_bi_rads_2_label = np.full(len(benign_bi_rads_2), 0)
benign_bi_rads_3_label = np.full(len(benign_bi_rads_3),1)
malignant_bi_rads_4_label = np.full(len(malignant_bi_rads_4),2)
malignant_bi_rads_5_label = np.full(len(malignant_bi_rads_5),3)

# %%
X = np.concatenate((benign_bi_rads_2, benign_bi_rads_3, malignant_bi_rads_4, malignant_bi_rads_5), axis = 0)
Y = np.concatenate((benign_bi_rads_2_label, benign_bi_rads_3_label, malignant_bi_rads_4_label, malignant_bi_rads_5_label), axis = 0)

# Shuffle train data
s = np.arange(X.shape[0])
np.random.shuffle(s)
X = X[s]
Y = Y[s]

# PREPROCESSING for BETTER RESULT
X = X.astype("float32") / 255.0

# %%
x_train, x_test, y_train, y_test = train_test_split(
    X, Y, 
    test_size=0.2, 
    random_state=11,
    stratify=Y
)

x_train, x_val, y_train, y_val = train_test_split(
    x_train, y_train, 
    test_size=0.2, 
    random_state=11,
    stratify=y_train
)

# %%
print("\nFinal Shapes:")
print("x_train:", x_train.shape)
print("y_train:", y_train.shape)
print("x_val:", x_val.shape)
print("y_val:", y_val.shape)
print("x_test:", x_test.shape)
print("y_test:", y_test.shape)
# Out:
# Final Shapes:
# x_train: (105, 224, 224, 3)
# y_train: (105,)
# x_val: (27, 224, 224, 3)
# y_val: (27,)
# x_test: (34, 224, 224, 3)
# y_test: (34,)

# %%
from imblearn.over_sampling import RandomOverSampler
from tensorflow.keras.utils import to_categorical
from collections import Counter
import numpy as np

# Convert one-hot -> labels if needed
if len(y_train.shape) > 1:
    y_train_labels = np.argmax(y_train, axis=1)
else:
    y_train_labels = y_train

# Check original distribution
print("Original class distribution:")
print(Counter(y_train_labels))

# Flatten image data temporarily
nsamples, h, w, c = x_train.shape

x_train_flat = x_train.reshape(
    (nsamples, h * w * c)
)

target = 1200

sampling_strategy = {
    0: target,
    1: target,
    2: target,
    3: target
}

# Apply Oversampling
ros = RandomOverSampler(
    sampling_strategy=sampling_strategy,
    random_state=42
)

x_train, y_train = ros.fit_resample(
    x_train_flat,
    y_train_labels
)

# Restore image shape
x_train = x_train.reshape(
    (-1, h, w, c)
)

# One-hot Encode Labels
y_train = to_categorical(
    y_train,
    num_classes=4
)

# Validation labels
if len(y_val.shape) == 1:
    y_val = to_categorical(y_val, num_classes=4)

# Test labels
if len(y_test.shape) == 1:
    y_test = to_categorical(y_test, num_classes=4)
    
# Final Distribution
print("\nBalanced class distribution:")
print(Counter(np.argmax(y_train, axis=1)))
# Out:
# Original class distribution:
# Counter({np.int64(2): 34, np.int64(3): 30, np.int64(1): 30, np.int64(0): 11})
#
# Balanced class distribution:
# Counter({np.int64(2): 1200, np.int64(3): 1200, np.int64(0): 1200, np.int64(1): 1200})

# %%
BATCH_SIZE = 32

# Using original generator
train_generator = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.2,
    shear_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    vertical_flip=False
)

# %%
IMAGE_SIZE = 224

input_shape = (IMAGE_SIZE, IMAGE_SIZE, 3)
inputs = Input(input_shape)

resnet50 = ResNet50(include_top=False,weights='imagenet',input_shape=input_shape)(inputs)
effnetv2 = EfficientNetV2B0(include_top=False,weights='imagenet',input_shape=input_shape)(inputs)
vgg16 = VGG16(include_top=False,weights='imagenet',input_shape=input_shape)(inputs)
# Out:
# I0000 00:00:1780769627.592426      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1780769627.598443      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b0_notop.h5
# 24274472/24274472 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
outputs = Concatenate(axis=-1)([GlobalAveragePooling2D()(resnet50),GlobalAveragePooling2D()(effnetv2),GlobalAveragePooling2D()(vgg16)])
outputs = BatchNormalization()(outputs)
outputs = Dense(256, activation='relu')(outputs)
outputs = Dropout(0.4)(outputs)
outputs = Dense(128, activation='relu')(outputs)
outputs = Dropout(0.2)(outputs)
outputs = Dense(4, activation='softmax')(outputs)

model = Model(inputs, outputs)
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ resnet50            │ (None, 7, 7,      │ 23,587,712 │ input_layer[0][0] │
# │ (Functional)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ efficientnetv2-b0   │ (None, 7, 7,      │  5,919,312 │ input_layer[0][0] │
# │ (Functional)        │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vgg16 (Functional)  │ (None, 7, 7, 512) │ 14,714,688 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2048)      │          0 │ resnet50[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ efficientnetv2-b… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ vgg16[0][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 3840)      │          0 │ global_average_p… │
# │ (Concatenate)       │                   │            │ global_average_p… │
# │                     │                   │            │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 3840)      │     15,360 │ concatenate[0][0] │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │    983,296 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 128)       │     32,896 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128)       │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 4)         │        516 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 45,253,780 (172.63 MB)
#  Trainable params: 45,132,372 (172.17 MB)
#  Non-trainable params: 121,408 (474.25 KB)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

filepath = "/kaggle/working/MultiNet_ResNet50_EfficientNetV2B0_VGG16.keras"

checkpoint = ModelCheckpoint(
    filepath,
    monitor='val_accuracy',
    verbose=1,
    save_best_only=True,
    mode='max'
)

# Early stopping
early_stopping = EarlyStopping(
    monitor='val_accuracy',  
    patience=8,             
    verbose=1,
    mode='max',
    restore_best_weights=True
)

learn_control = ReduceLROnPlateau(
    monitor='val_loss',
    patience=3,
    factor=0.3,
    min_lr=1e-6,
    verbose=1
)

# %%
history = model.fit(
    train_generator.flow(x_train,y_train,batch_size=BATCH_SIZE),
    epochs=100,
    validation_data=(x_val, y_val),
    callbacks=[checkpoint,early_stopping,learn_control]
)
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1780769704.920275      69 service.cc:152] XLA service 0x791224002a40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1780769704.920361      69 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1780769704.920367      69 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1780769717.861522      69 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2026-06-06 18:15:33.662868: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-06 18:15:33.801246: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-06 18:15:35.223520: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-06 18:15:35.364268: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-06 18:15:52.773948: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-06 18:15:52.970801: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-06 18:15:54.682504: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-06 18:15:54.856164: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-06 18:15:58.755405: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-06 18:15:59.086981: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-06 18:16:09.989617: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-06 18:16:10.130157: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-06 18:16:12.451793: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-06 18:16:12.591797: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-06 18:16:14.839667: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-06 18:16:14.980281: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1780769821.952026      69 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 852ms/step - accuracy: 0.5656 - loss: 1.0706
# 2026-06-06 18:19:23.016126: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-06 18:19:23.152810: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-06 18:19:24.522205: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-06 18:19:24.662497: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-06 18:19:24.803232: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# Epoch 1: val_accuracy improved from None to 0.25926, saving model to /kaggle/working/MultiNet_ResNet50_EfficientNetV2B0_VGG16.keras
#
# Epoch 1: finished saving model to /kaggle/working/MultiNet_ResNet50_EfficientNetV2B0_VGG16.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 350s 1s/step - accuracy: 0.7471 - loss: 0.6302 - val_accuracy: 0.2593 - val_loss: 2.0456 - learning_rate: 1.0000e-04
# Epoch 2/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.9384 - loss: 0.1761
# Epoch 2: val_accuracy improved from 0.25926 to 0.29630, saving model to /kaggle/working/MultiNet_ResNet50_EfficientNetV2B0_VGG16.keras
#
# Epoch 2: finished saving model to /kaggle/working/MultiNet_ResNet50_EfficientNetV2B0_VGG16.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 135s 899ms/step - accuracy: 0.9540 - loss: 0.1398 - val_accuracy: 0.2963 - val_loss: 2.2190 - learning_rate: 1.0000e-04
# Epoch 3/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 878ms/step - accuracy: 0.9820 - loss: 0.0630
# Epoch 3: val_accuracy did not improve from 0.29630
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 132s 880ms/step - accuracy: 0.9808 - loss: 0.0632 - val_accuracy: 0.2593 - val_loss: 4.4965 - learning_rate: 1.0000e-04
# Epoch 4/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 882ms/step - accuracy: 0.9852 - loss: 0.0495
# Epoch 4: val_accuracy did not improve from 0.29630
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 133s 884ms/step - accuracy: 0.9825 - loss: 0.0574 - val_accuracy: 0.2593 - val_loss: 4.3963 - learning_rate: 1.0000e-04
# Epoch 5/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 882ms/step - accuracy: 0.9926 - loss: 0.0268
# Epoch 5: val_accuracy improved from 0.29630 to 0.37037, saving model to /kaggle/working/MultiNet_ResNet50_EfficientNetV2B0_VGG16.keras
#
# Epoch 5: finished saving model to /kaggle/working/MultiNet_ResNet50_EfficientNetV2B0_VGG16.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 137s 910ms/step - accuracy: 0.9946 - loss: 0.0192 - val_accuracy: 0.3704 - val_loss: 3.3686 - learning_rate: 3.0000e-05
# Epoch 6/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 881ms/step - accuracy: 0.9980 - loss: 0.0089
# Epoch 6: val_accuracy did not improve from 0.37037
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 133s 883ms/step - accuracy: 0.9981 - loss: 0.0081 - val_accuracy: 0.2593 - val_loss: 3.4777 - learning_rate: 3.0000e-05
# Epoch 7/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 883ms/step - accuracy: 0.9978 - loss: 0.0071
# Epoch 7: val_accuracy did not improve from 0.37037
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 133s 885ms/step - accuracy: 0.9977 - loss: 0.0084 - val_accuracy: 0.2593 - val_loss: 3.1776 - learning_rate: 3.0000e-05
# Epoch 8/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 883ms/step - accuracy: 0.9991 - loss: 0.0054
# Epoch 8: val_accuracy did not improve from 0.37037
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 133s 885ms/step - accuracy: 0.9990 - loss: 0.0062 - val_accuracy: 0.3333 - val_loss: 3.4203 - learning_rate: 9.0000e-06
# Epoch 9/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 883ms/step - accuracy: 0.9983 - loss: 0.0054
# Epoch 9: val_accuracy improved from 0.37037 to 0.40741, saving model to /kaggle/working/MultiNet_ResNet50_EfficientNetV2B0_VGG16.keras
#
# Epoch 9: finished saving model to /kaggle/working/MultiNet_ResNet50_EfficientNetV2B0_VGG16.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 137s 912ms/step - accuracy: 0.9985 - loss: 0.0052 - val_accuracy: 0.4074 - val_loss: 3.4608 - learning_rate: 9.0000e-06
# Epoch 10/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 881ms/step - accuracy: 0.9979 - loss: 0.0052
# Epoch 10: val_accuracy did not improve from 0.40741
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 133s 883ms/step - accuracy: 0.9985 - loss: 0.0045 - val_accuracy: 0.4074 - val_loss: 3.2241 - learning_rate: 9.0000e-06
# Epoch 11/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 883ms/step - accuracy: 0.9990 - loss: 0.0053
# Epoch 11: val_accuracy did not improve from 0.40741
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 133s 885ms/step - accuracy: 0.9990 - loss: 0.0052 - val_accuracy: 0.2963 - val_loss: 3.2745 - learning_rate: 2.7000e-06
# Epoch 12/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 884ms/step - accuracy: 0.9988 - loss: 0.0038
# Epoch 12: val_accuracy did not improve from 0.40741
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 133s 886ms/step - accuracy: 0.9990 - loss: 0.0049 - val_accuracy: 0.3333 - val_loss: 3.9097 - learning_rate: 2.7000e-06
# Epoch 13/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 883ms/step - accuracy: 0.9979 - loss: 0.0036
# Epoch 13: val_accuracy did not improve from 0.40741
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 133s 885ms/step - accuracy: 0.9990 - loss: 0.0030 - val_accuracy: 0.3333 - val_loss: 4.0672 - learning_rate: 2.7000e-06
# Epoch 14/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 883ms/step - accuracy: 0.9995 - loss: 0.0026
# Epoch 14: val_accuracy did not improve from 0.40741
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 133s 885ms/step - accuracy: 0.9990 - loss: 0.0040 - val_accuracy: 0.3333 - val_loss: 4.1411 - learning_rate: 1.0000e-06
# Epoch 15/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 883ms/step - accuracy: 0.9988 - loss: 0.0047
# Epoch 15: val_accuracy did not improve from 0.40741
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 133s 885ms/step - accuracy: 0.9992 - loss: 0.0038 - val_accuracy: 0.3333 - val_loss: 4.2040 - learning_rate: 1.0000e-06
# Epoch 16/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 883ms/step - accuracy: 0.9993 - loss: 0.0028
# Epoch 16: val_accuracy did not improve from 0.40741
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 133s 885ms/step - accuracy: 0.9990 - loss: 0.0031 - val_accuracy: 0.3333 - val_loss: 4.1536 - learning_rate: 1.0000e-06
# Epoch 17/100
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 883ms/step - accuracy: 0.9989 - loss: 0.0035
# Epoch 17: val_accuracy did not improve from 0.40741
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 133s 885ms/step - accuracy: 0.9987 - loss: 0.0038 - val_accuracy: 0.3333 - val_loss: 4.1157 - learning_rate: 1.0000e-06
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 9.

# %%
y_pred = model.predict(x_test)
# Out:
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 21s 22s/step
# 2026-06-06 18:55:54.994640: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-06 18:55:55.127943: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-06 18:55:56.481020: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-06 18:55:56.621513: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 40s 18s/step

# %%
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=55)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

cm = confusion_matrix(np.argmax(y_test, axis=1), np.argmax(y_pred, axis=1))

cm_plot_label =['Benign (BI-RADS 2)', 'Benign (BI-RADS 3)', 'Malign (BI-RADS 4)', 'Malign (BI-RADS 5)']
plot_confusion_matrix(cm, cm_plot_label, title ='Multiclass Confusion Matrix')
# Out:
# Confusion matrix, without normalization
# [[1 2 1 0]
#  [1 2 0 7]
#  [0 8 1 2]
#  [1 3 0 5]]

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

t = f.suptitle('MultiNet: ResNet50 + ResNet50V2 + EfficientNetV2B0 Fusion',fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

# Dynamic epoch count
epoch_list = range(1, len(history.history['accuracy']) + 1)

# Accuracy Plot
ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')

ax1.grid()
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
ax1.legend(loc="best")

# Loss Plot
ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')

ax2.grid()
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
ax2.legend(loc="best")

plt.show()

# %%
print("y_test:", y_test.shape)
print("y_pred:", y_pred.shape)
# Out:
# y_test: (34, 4)
# y_pred: (34, 4)

# %%
import numpy as np
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    matthews_corrcoef,
    mean_absolute_error,
    mean_squared_error,
    cohen_kappa_score
)

# Predictions
pred = model.predict(x_test)
y_pred = np.argmax(pred, axis=1)
y_test = np.argmax(y_test, axis=1)

# Target labels
target_names = [
    'Benign (BI-RADS 2)',
    'Benign (BI-RADS 3)',
    'Malign (BI-RADS 4)',
    'Malign (BI-RADS 5)'
]

# Classification Report
print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=target_names))

# Confusion Matrix
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

# Additional Metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')
mcc = matthews_corrcoef(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
kappa = cohen_kappa_score(y_test, y_pred)

# Print all metrics
print("\nAdditional Evaluation Metrics:")
print(f"Accuracy       : {accuracy:.4f}")
print(f"Precision      : {precision:.4f}")
print(f"Recall         : {recall:.4f}")
print(f"F1-score       : {f1:.4f}")
print(f"MCC            : {mcc:.4f}")
print(f"MAE            : {mae:.4f}")
print(f"MSE            : {mse:.4f}")
print(f"Cohen's Kappa  : {kappa:.4f}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Classification Report:
#                     precision    recall  f1-score   support
#
# Benign (BI-RADS 2)       0.33      0.25      0.29         4
# Benign (BI-RADS 3)       0.13      0.20      0.16        10
# Malign (BI-RADS 4)       0.50      0.09      0.15        11
# Malign (BI-RADS 5)       0.36      0.56      0.43         9
#
#           accuracy                           0.26        34
#          macro avg       0.33      0.27      0.26        34
#       weighted avg       0.33      0.26      0.25        34
#
# Confusion Matrix:
# [[1 2 1 0]
#  [1 2 0 7]
#  [0 8 1 2]
#  [1 3 0 5]]
#
# Additional Evaluation Metrics:
# Accuracy       : 0.2647
# Precision      : 0.3347
# Recall         : 0.2647
# F1-score       : 0.2455
# MCC            : -0.0051
# MAE            : 1.1176
# MSE            : 1.9412
# Cohen's Kappa  : -0.0047
